# %% [markdown]
# ## Item similarity based recommender systems

# %%
import numpy as np
import pandas as pd

# %%
columns_names = ['user_id','item_id','rating','timestamp']

# %%
df = pd.read_csv('files/19-Recommender-Systems/u.data',sep='\t',names = columns_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movie_titles = pd.read_csv("files/19-Recommender-Systems/Movie_Id_Titles")

# %%
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df = pd.merge(df,movie_titles,on="item_id")

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['Number of Ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())

# %%
ratings.head()
# Out:
#                              rating  Number of Ratings
# title
# 'Til There Was You (1997)  2.333333                  9
# 1-900 (1994)               2.600000                  5
# 101 Dalmatians (1996)      2.908257                109
# 12 Angry Men (1957)        4.344000                125
# 187 (1997)                 3.024390                 41

# %%
ratings['Number of Ratings'].hist(bins=70)

# %%
ratings['rating'].hist(bins=70)

# %%
sns.jointplot(x="rating",y="Number of Ratings",data=ratings)

# %% [markdown]
# ## Now We Recommend

# %%
movie_mat = df.pivot_table(index="user_id",columns="title",values="rating")

# %%
movie_mat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
ratings.sort_values('Number of Ratings',ascending=False)
# Out:
#                                                       rating  \
# title
# Star Wars (1977)                                    4.359589
# Contact (1997)                                      3.803536
# Fargo (1996)                                        4.155512
# Return of the Jedi (1983)                           4.007890
# Liar Liar (1997)                                    3.156701
# English Patient, The (1996)                         3.656965
# Scream (1996)                                       3.441423
# Toy Story (1995)                                    3.878319
# Air Force One (1997)                                3.631090
# Independence Day (ID4) (1996)                       3.438228
# Raiders of the Lost Ark (1981)                      4.252381
# Godfather, The (1972)                               4.283293
# Pulp Fiction (1994)                                 4.060914
# Twelve Monkeys (1995)                               3.798469
# ...

# %%
star_wars_users_ratings = movie_mat['Star Wars (1977)']
liar_liar_user_ratings=movie_mat['Liar Liar (1997)']

# %%
star_wars_users_ratings
# Out:
# user_id
# 0      5.0
# 1      5.0
# 2      5.0
# 3      NaN
# 4      5.0
# 5      4.0
# 6      4.0
# 7      5.0
# 8      5.0
# 9      5.0
# 10     5.0
# 11     NaN
# 12     4.0
# 13     5.0
# 14     5.0
# 15     5.0
# 16     NaN
# 17     NaN
# 18     4.0
# 19     NaN
# 20     3.0
# 21     3.0
# 22     5.0
# 23     4.0
# 24     NaN
# 25     5.0
# 26     4.0
# 27     3.0
# 28     4.0
# 29     NaN
#       ...
# 914    NaN
# 915    NaN
# 916    5.0
# 917    3.0
# 918    NaN
# 919    3.0
# 920    NaN
# 921    4.0
# 922    5.0
# 923    5.0
# 924    5.0
# 925    NaN
# 926    NaN
# 927    NaN
# 928    NaN
# 929    4.0
# 930    2.0
# 931    3.0
# 932    NaN
# 933    4.0
# 934    5.0
# 935    NaN
# 936    4.0
# 937    5.0
# 938    5.0
# 939    NaN
# 940    4.0
# 941    NaN
# 942    5.0
# 943    4.0
# Name: Star Wars (1977), Length: 944, dtype: float64

# %%
similar_star_wars = movie_mat.corrwith(star_wars_users_ratings)

# %%
similar_liar_liar = movie_mat.corrwith(liar_liar_user_ratings)
# Out:
# C:\Users\Dheeru\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\Dheeru\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_starwars = pd.DataFrame(similar_star_wars,columns=['Correlations'])
corr_starwars.dropna(inplace=True)

# %%
corr_starwars
# Out:
#                                                     Correlations
# title
# 'Til There Was You (1997)                               0.872872
# 1-900 (1994)                                           -0.645497
# 101 Dalmatians (1996)                                   0.211132
# 12 Angry Men (1957)                                     0.184289
# 187 (1997)                                              0.027398
# 2 Days in the Valley (1996)                             0.066654
# 20,000 Leagues Under the Sea (1954)                     0.289768
# 2001: A Space Odyssey (1968)                            0.230884
# 39 Steps, The (1935)                                    0.106453
# 8 1/2 (1963)                                           -0.142977
# 8 Heads in a Duffel Bag (1997)                         -0.577350
# 8 Seconds (1994)                                       -0.755929
# A Chef in Love (1996)                                   0.868599
# ...

# %%
corr_starwars = corr_starwars.join(ratings['Number of Ratings'])

# %%
corr_starwars.head()
# Out:
#                            Correlations  Number of Ratings
# title
# 'Til There Was You (1997)      0.872872                  9
# 1-900 (1994)                  -0.645497                  5
# 101 Dalmatians (1996)          0.211132                109
# 12 Angry Men (1957)            0.184289                125
# 187 (1997)                     0.027398                 41

# %%
corr_starwars[corr_starwars['Number of Ratings']>100].sort_values('Correlations',ascending=False).head()
# Out:
#                                                     Correlations  \
# title
# Star Wars (1977)                                        1.000000
# Empire Strikes Back, The (1980)                         0.748353
# Return of the Jedi (1983)                               0.672556
# Raiders of the Lost Ark (1981)                          0.536117
# Austin Powers: International Man of Mystery (1997)      0.377433
#
#                                                     Number of Ratings
# title
# Star Wars (1977)                                                  584
# Empire Strikes Back, The (1980)                                   368
# Return of the Jedi (1983)                                         507
# Raiders of the Lost Ark (1981)                                    420
# Austin Powers: International Man of Mystery (1997)                130

# %%
corr_liar_liar = pd.DataFrame(similar_liar_liar,columns=['Correlations'])

# %%
corr_liar_liar.head()
# Out:
#                            Correlations
# title
# 'Til There Was You (1997)      0.118913
# 1-900 (1994)                        NaN
# 101 Dalmatians (1996)          0.469765
# 12 Angry Men (1957)            0.066272
# 187 (1997)                     0.175145

# %%
corr_liar_liar.dropna(inplace=True)

# %%
corr_liar_liar=corr_liar_liar.join(ratings['Number of Ratings'])

# %%
corr_liar_liar[corr_liar_liar['Number of Ratings']>100].sort_values('Correlations',ascending=False).head()
# Out:
#                        Correlations  Number of Ratings
# title
# Liar Liar (1997)           1.000000                485
# Batman Forever (1995)      0.516968                114
# Mask, The (1994)           0.484650                129
# Down Periscope (1996)      0.472681                101
# Con Air (1997)             0.469828                137
